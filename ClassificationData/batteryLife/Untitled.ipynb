# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("battery.csv",header=None,names=['charge-time','battery-life'],sep=',')

# %%
train_data=data.iloc[:,[0]]
test_data=data.iloc[:,[1]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(train_data,test_data,random_state=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
# charge-time     100 non-null float64
# battery-life    100 non-null float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
predict=lr.predict([[float(input())]])
# Out:
# 4.3

# %%
print(predict[0][0])
# Out:
# 5.92940951589

# %%
plt.xlabel("Charging Time")
plt.ylabel("Battery RunTime")
plt.scatter(X_train,y_train,s=3)

# %%
train_data
# Out:
#     charge-time
# 0          2.81
# 1          7.14
# 2          2.72
# 3          3.87
# 4          1.90
# 5          7.82
# 6          7.02
# 7          5.50
# 8          9.15
# 9          4.87
# 10         8.08
# 11         5.58
# 12         9.13
# 13         0.14
# 14         2.00
# 15         5.47
# 16         0.80
# 17         4.37
# 18         5.31
# 19         0.00
# 20         1.78
# 21         3.45
# 22         6.13
# 23         3.53
# 24         4.61
# 25         1.76
# 26         6.39
# 27         0.02
# 28         9.69
# 29         5.33
# ..          ...
# 70         5.39
# 71         3.47
# 72         6.48
# 73         4.11
# 74         1.85
# 75         8.79
# 76         0.13
# 77         1.44
# 78         5.96
# 79         3.42
# 80         1.89
# 81         1.98
# 82         5.26
# 83         0.39
# 84         6.05
# 85         1.99
# 86         1.58
# 87         3.99
# 88         4.35
# 89         6.71
# 90         2.58
# 91         7.37
# 92         5.77
# ...

# %%
test_data
# Out:
#     battery-life
# 0           5.62
# 1           8.00
# 2           5.44
# 3           7.74
# 4           3.80
# 5           8.00
# 6           8.00
# 7           8.00
# 8           8.00
# 9           8.00
# 10          8.00
# 11          8.00
# 12          8.00
# 13          0.28
# 14          4.00
# 15          8.00
# 16          1.60
# 17          8.00
# 18          8.00
# 19          0.00
# 20          3.56
# 21          6.90
# 22          8.00
# 23          7.06
# 24          8.00
# 25          3.52
# 26          8.00
# 27          0.04
# 28          8.00
# 29          8.00
# ..           ...
# 70          8.00
# 71          6.94
# 72          8.00
# 73          8.00
# 74          3.70
# 75          8.00
# 76          0.26
# 77          2.88
# 78          8.00
# 79          6.84
# 80          3.78
# 81          3.96
# 82          8.00
# 83          0.78
# 84          8.00
# 85          3.98
# 86          3.16
# 87          7.98
# 88          8.00
# 89          8.00
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
y_train
# Out:
#     battery-life
# 35          4.48
# 94          7.30
# 27          0.04
# 46          8.00
# 38          8.00
# 67          8.00
# 99          8.00
# 54          8.00
# 95          8.00
# 88          8.00
# 40          3.66
# 48          3.50
# 59          8.00
# 23          7.06
# 34          8.00
# 86          3.16
# 53          7.94
# 77          2.88
# 15          8.00
# 83          0.78
# 41          8.00
# 45          8.00
# 91          8.00
# 26          8.00
# 98          2.20
# 43          2.28
# 55          8.00
# 24          8.00
# 4           3.80
# 58          4.08
# ..           ...
# 57          3.32
# 22          8.00
# 61          8.00
# 63          8.00
# 7           8.00
# 96          8.00
# 13          0.28
# 68          2.54
# 85          3.98
# 14          4.00
# 29          8.00
# 28          8.00
# 11          8.00
# 18          8.00
# 20          3.56
# 50          8.00
# 25          3.52
# 6           8.00
# 71          6.94
# 76          0.26
# ...

# %%
y_train_std=y_train['battery-life'].apply(lambda x: int(x))

# %%
y_train_std
# Out:
# 35    4
# 94    7
# 27    0
# 46    8
# 38    8
# 67    8
# 99    8
# 54    8
# 95    8
# 88    8
# 40    3
# 48    3
# 59    8
# 23    7
# 34    8
# 86    3
# 53    7
# 77    2
# 15    8
# 83    0
# 41    8
# 45    8
# 91    8
# 26    8
# 98    2
# 43    2
# 55    8
# 24    8
# 4     3
# 58    4
#      ..
# 57    3
# 22    8
# 61    8
# 63    8
# 7     8
# 96    8
# 13    0
# 68    2
# 85    3
# 14    4
# 29    8
# 28    8
# 11    8
# 18    8
# 20    3
# 50    8
# 25    3
# 6     8
# 71    6
# 76    0
# 1     8
# 16    1
# 64    3
# 79    6
# 5     8
# 75    8
# 9     8
# 72    8
# 12    8
# 37    2
# Name: battery-life, Length: 75, dtype: int64

# %%
knn.fit(X_train,y_train_std)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
p=knn.predict([[4]])

# %%
print(p)
# Out:
# [7]

# %%
p[0]
# Out:
# 3

# %%
p[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-28e6e4853d9d> in <module>()
# ----> 1 p[1]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
p[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-21c545b39f61> in <module>()
# ----> 1 p[2]
#
# IndexError: index 2 is out of bounds for axis 0 with size 1
